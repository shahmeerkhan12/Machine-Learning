# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.image import imread

# %%
img_data = imread('BingWallpaper (27).jpg')

# %%
img_data
# Out:
# array([[[ 39,  31,  20],
#         [ 39,  31,  20],
#         [ 39,  31,  20],
#         ...,
#         [ 59,  42,  22],
#         [ 59,  42,  22],
#         [ 59,  42,  22]],
#
#        [[ 39,  31,  20],
#         [ 39,  31,  20],
#         [ 39,  31,  20],
#         ...,
#         [ 58,  41,  21],
#         [ 58,  41,  21],
#         [ 58,  41,  21]],
#
#        [[ 39,  31,  20],
#         [ 39,  31,  20],
#         [ 39,  31,  20],
#         ...,
#         [ 57,  40,  20],
#         [ 57,  40,  20],
#         [ 57,  40,  20]],
#
#        ...,
#
#        [[151, 163, 175],
#         [150, 162, 174],
#         [150, 162, 174],
#         ...,
#         [ 87,  97, 109],
#         [ 87,  97, 109],
#         [ 93, 103, 115]],
#
#        [[149, 161, 173],
#         [148, 160, 172],
#         [149, 161, 173],
#         ...,
#         [ 84,  94, 106],
#         [ 84,  94, 106],
#         [ 90, 100, 112]],
#
#        [[151, 163, 175],
#         [150, 162, 174],
#         [151, 163, 175],
# ...

# %%
plt.figure()

# %%
plt.imshow(img_data)

# %%
plt.show()
