# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()# shows empty braces
#plt.show() # shows a canvas representing x and y-axis
# Out:
# []

# %%
x = [10,20,30,40,50,60]
y = [70,35,17,7,4,2]

plt.plot(x,y)

# give this labels
plt.xlabel("No of labour")
plt.ylabel("No of Hours")
# also give it title
plt.title("Working-Hours vs No of Men")
plt.show()
